# %% [markdown]
# # Scraping Hotel Ratings on Booking #

# %% [markdown]
# In this homework we will practice web scraping on the following [site](https://www.booking.com/searchresults.html?label=gen173nr-1DCAEoggJCAlhYSDNYBHIFdXNfbWGIAQGYATG4AQfIAQ3YAQPoAQH4AQKSAgF5qAID&sid=991709bb93b40898e2ebcc9f2e20ade5&class_interval=1&dest_id=20088325&dest_type=city&from_sf=1&group_adults=2&group_children=0&label_click=undef&nflt=di%3D929%3B&no_rooms=1&pop_filter_id=di-929&pop_filter_pos=0&pop_filter_rank=2&raw_dest_type=city&room1=A%2CA&sb_price_type=total&search_selected=1&src=index&src_elem=sb&ss=New%20York%2C%20New%20York%20State%2C%20USA&ss_raw=new%20york&ssb=empty). Let's get some basic information for **each hotel in Manhattan (follow the above link) **.
# On each hotel page, scrape the following information:
# 1. Hotel Name
# 2. Class of Rating (Wonderful/Excellent/Very Good/Good)
# 3. Rating Score
#
# ** Save the data in "hotel_information.csv" in the following format: hotel_name, class_rating, rating **
#
# **(4 pts)**

# %%
from selenium import webdriver
from time import sleep
from bs4 import BeautifulSoup
import urllib.request

# %%
url = 'https://www.booking.com/searchresults.html?label=gen173nr-1DCAEoggJCAlhYSDNYBHIFdXNfbWGIAQGYATG4AQfIAQ3YAQPoAQH4AQKSAgF5qAID&sid=991709bb93b40898e2ebcc9f2e20ade5&class_interval=1&dest_id=20088325&dest_type=city&from_sf=1&group_adults=2&group_children=0&label_click=undef&nflt=di%3D929%3B&no_rooms=1&pop_filter_id=di-929&pop_filter_pos=0&pop_filter_rank=2&raw_dest_type=city&room1=A%2CA&sb_price_type=total&search_selected=1&src=index&src_elem=sb&ss=New%20York%2C%20New%20York%20State%2C%20USA&ss_raw=new%20york&ssb=empty'
page = urllib.request.urlopen(url)
soup = BeautifulSoup(page, 'lxml')

# %%
hotel_name = []
class_rate = []
rate = []
i = 1
hotels = soup.find_all('div', attrs={'class': "sr_item sr_item_new sr_item_default sr_property_block sr_item_no_dates "})
for hotel in hotels:
    name_box = hotel.find('span', attrs={'class': 'sr-hotel__name'})
    hotel_name.append(name_box.text.strip())
    if (hotel.find('span', attrs={'class': 'review-score-badge'}) == None):
        rate.append(None)
    else:
        rate_box = hotel.find('span', attrs={'class': 'review-score-badge'})
        rate.append(rate_box.text.strip())
    if (hotel.find('span', attrs={'class': 'review-score-widget__text'}) == None):
        class_rate.append(None)
    else:
        class_rate_box = hotel.find('span', attrs={'class': 'review-score-widget__text'})
        class_rate.append(class_rate_box.text.strip())
    i += 1

# %%
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys

actions = ActionChains(driver)

# %%
import pandas as pd
df=pd.DataFrame(hotel_name,columns=['hotel_name'])
df['class_rating'] = class_rate
df['rating'] = class_rate

df
# Out:
#                                            hotel_name class_rating     rating
# 0                                          MADE Hotel      Awesome    Awesome
# 1   Fairfield Inn & Suites by Marriott New York Do...    Excellent  Excellent
# 2                                       Tribeca Lofts    Very Good  Very Good
# 3       Luxury Two Bedroom Apartment - Midtown West J         None       None
# 4   Residence Inn by Marriott New York Manhattan/T...    Very Good  Very Good
# 5                               Radio City Apartments    Very Good  Very Good
# 6                                     Hotel 50 Bowery      Awesome    Awesome
# 7   Courtyard by Marriott New York Manhattan/Centr...    Very Good  Very Good
# 8                                   Freehand New York      Awesome    Awesome
# 9                               Archer Hotel New York      Awesome    Awesome
# 10                                   AKA Times Square    Excellent  Excellent
# 11                          Times Square Lux Highrise         Good       Good
# 12                                 Gramercy Townhouse         None       None
# 13                     Broadway at Times Square Hotel    Very Good  Very Good
# 14                                     Lombardy Hotel    Very Good  Very Good

# %%
import csv
from datetime import datetime
df.to_csv('hotel_information.csv', encoding='utf-8', index=False)

# %% [markdown]
# Now let's scrape some reviews. You can see all review information by going to the hotel page and accessing on “see all reviews” and then view the page sourceFor each review of each each hotel in Manhattan you are to scrape the following attributes:
# 1. Hotel name
# 2. Reviewer name
# 3. Number of helpful votes (if available, otherwise None)
# 4. Date
# 5. Review Rating
# 6. Negative Review (if available, otherwise None)
# 7. Positive Review (if available, otherwise None)
#
# Note that you will also need the hotel's name!! Also, some reviews may not have all attributes so then just add None in the corresponding column.
#
# ** Save the data in "review_ratings.csv" in the following format: hotel_name, reviewer_name, num_help_votes, date, review_rating, neg_review, pos_review **
#
# **(4 pts)**

# %%
url_MADE = "https://www.booking.com/hotel/us/made.html?label=gen173nr-1DCAEoggJCAlhYSDNYBHIFdXNfbWGIAQGYATG4AQfIAQ3YAQPoAQH4AQKSAgF5qAID;sid=657ba535f7e50f67543d1f6039b3a62e;dest_id=20088325;dest_type=city;dist=0;group_adults=2;hapos=1;hpos=1;nflt=di%3D929;room1=A%2CA;sb_price_type=total;srepoch=1521939404;srfid=a3abd319604ec777429571f9ccd1178591607840X1;srpvid=e18b06a5f0eb01b7;type=total;ucfs=1&#tab-reviews"
page = urllib.request.urlopen(url_MADE)
soup = BeautifulSoup(page, 'lxml')

# %%
hotel_name_box = soup.find('h2',  attrs={'class':'hp__hotel-name'})
hotel_name = hotel_name_box.text.strip()

# %%
reviews = soup.find_all('li', attrs={'class':'review_item clearfix '})
reviewer = []
num_vote = []
date = []
rating = []
neg_review = []
pos_review = []
for review in reviews:
    reviewer_box = review.find('div',attrs={'class':'review_item_reviewer'})
    reviewer_box = reviewer_box.find('h4')
    reviewer.append(reviewer_box.text.strip())
    print(reviewer_box.text.strip())
    
    if (review.find('div', attrs={'class': 'review_item_user_helpful_count'}) == None):
        num_vote.append(None)
        print(None)
    else:
        num_vote_box = review.find('div', attrs={'class': 'review_item_user_helpful_count'})
        num_vote.append(num_vote_box.text.strip())
        print(num_vote_box.text.strip())
        
    date_box = review.find('p',attrs={'class':'review_item_date'})
    date.append(date_box.text.strip()[10:])
    print(date_box.text.strip()[10:])

    rating_box = review.find('span',attrs={'class':'review-score-badge'})
    rating.append(rating_box.text.strip())
    print(rating_box.text.strip())   
    
    if (review.find('p', attrs={'class': 'review_neg '}) == None):
        neg_review.append(None)
        print(None)
    else:
        neg_review_box = review.find('p', attrs={'class': 'review_neg '})
        neg_review.append(neg_review_box.text.strip()[1:])
        print(neg_review_box.text.strip()[1:])
    
    if (review.find('p', attrs={'class': 'review_pos '}) == None):
        pos_review.append(None)
        print(None)
    else:
        pos_review_box = review.find('p', attrs={'class': 'review_pos '})
        pos_review.append(pos_review_box.text.strip()[1:])
        print(pos_review_box.text.strip()[1:])

    print("============")
# Out:
# NatGH
# None
# March 23, 2018
# 9.6
# No fridge and no coffee in the room.
# Design of the room, confort, quality of services, warm welcome, location.
# ============
# Avishai
# None
# March 23, 2018
# 10
# None
# Great friendly staff, cool rooms
# ============
# Leah
# None
# March 23, 2018
# 8.3
# items within the room are ridiculously pricey. I was super thirsty in the middle of the night but refused to drink the water seeing that it costed $6 for just one bottle.
# The bed was lit.
# ============
# Kim
# 2 helpful votes
# March 22, 2018
# 10
# I only wish I could have stayed longer.
# Brand spanking new hotel. Young, fresh and hip. I am none of those things and yet every person we encountered treated us with professionalism, courtesy, and genuine joy. The room was a delight and the breakfast amazing. I wish my flat looked like their rooms. Special shout out to Michele, who is the Queen of the Breakfast Bar, and manager Steven who was so kind when we were terribly jet lagged. Highly, highly recommended!
# ============
# Jill
# None
# March 21, 2018
# 10
# No coffee or mini fridge in room
# Room was awesome....bed was extra comfy!!!
# ============
# Savanna
# None
# March 19, 2018
# 10
# None
# Eddie at the front desk was especially kind and gracious.
# ============
# Peter
# None
# March 17, 2018
# 10
# None
# the chia pudding is amazing at breakfast
# ============
# LUMILU
# 2 helpful votes
# March 16, 2018
# 10
# None
# The roof top
# ============
# Anonymous
# None
# March 16, 2018
# 10
# None
# Really yummy breakfast with a variety of traditional and healthy options; full english/granola/chia pudding/egg and avocado on toast etc. Rooms were beautifully presented and clean, very well designed, loved them! Good vibe overall to the hotel, very happy.
# ============
# Matteo
# None
# March 15, 2018
# 10
# Everything was just perfect
# The design is absolutely stunning, very nice room, comfortable and clean. The Staff is very kind and had a nice chat with Michelle at breakfast. The location is perfect:right where you want to be!
# ============
# Alexie
# None
# March 14, 2018
# 8.5
# the robes had dark stain on the inside, I hope they could check that more carefully.
# Great location and warm staffs. Room was a bit small but well designed.
# ============
# Monica
# None
# March 12, 2018
# 10
# None
# I love the staff, especially Iman at the front desk, and MICHELLE! She always remembers my name (and this is my 3rd time back to the hotel).  Having that Paper Coffee there in the morning with the Granola to go, was AMAZING! The lounge/bar area was also incredible to come back and chill with a glass of wine, good music, great ambiance and service.  The rooms are cozy, bedding is amazing.  I love the products offered by Davines, my fave.  I will always stay here, and have recommended to all of my friends and coworker.
# ============
# Penny
# None
# March 12, 2018
# 9.6
# None
# All the staff
# ============
# Bertrand
# None
# March 12, 2018
# 9.6
# None
# Well thought bedrooms, very classy and comfortable hotel !
# ============
# Kailin
# None
# March 12, 2018
# 8.8
# The hotel locates in a quiet street so this should be a quiet night. However, girls next door were having a crazing night. Can hear every word they say all night long even with ear plug... so did not get a good sleep or get my work down...
# I like the room design. Shower and bedding are comfortable. Room temperature is good. Staff are polite and nice.
# ============

# %%
hotel = [hotel_name]* len(reviewer)
df=pd.DataFrame(hotel,columns=['hotel_name'])

# df['reviewer_name'] = reviewer
df['num_help_votes'] = num_vote
df['date'] = date
df['review_rating'] = rating
df['neg_review'] = neg_review
df['pos_review'] = pos_review

df
# Out:
#     hotel_name   num_help_votes            date review_rating  \
# 0   MADE Hotel             None  March 23, 2018           9.6
# 1   MADE Hotel             None  March 23, 2018            10
# 2   MADE Hotel             None  March 23, 2018           8.3
# 3   MADE Hotel  2 helpful votes  March 22, 2018            10
# 4   MADE Hotel             None  March 21, 2018            10
# 5   MADE Hotel             None  March 19, 2018            10
# 6   MADE Hotel             None  March 17, 2018            10
# 7   MADE Hotel  2 helpful votes  March 16, 2018            10
# 8   MADE Hotel             None  March 16, 2018            10
# 9   MADE Hotel             None  March 15, 2018            10
# 10  MADE Hotel             None  March 14, 2018           8.5
# 11  MADE Hotel             None  March 12, 2018            10
# 12  MADE Hotel             None  March 12, 2018           9.6
# 13  MADE Hotel             None  March 12, 2018           9.6
# 14  MADE Hotel             None  March 12, 2018           8.8
#
#                                            neg_review  \
# 0                No fridge and no coffee in the room.
# 1                                                None
# 2   items within the room are ridiculously pricey....
# 3             I only wish I could have stayed longer.
# 4                    No coffee or mini fridge in room
# 5                                                None
# 6                                                None
# 7                                                None
# 8                                                None
# 9                         Everything was just perfect
# 10  the robes had dark stain on the inside, I hope...
# 11                                               None
# 12                                               None
# 13                                               None
# 14  The hotel locates in a quiet street so this sh...
#
#                                            pos_review
# 0   Design of the room, confort, quality of servic...
# 1                    Great friendly staff, cool rooms
# 2                                    The bed was lit.
# 3   Brand spanking new hotel. Young, fresh and hip...
# 4          Room was awesome....bed was extra comfy!!!
# 5   Eddie at the front desk was especially kind an...
# 6            the chia pudding is amazing at breakfast
# 7   The location\rThe interior design\rThe friendl...
# 8   Really yummy breakfast with a variety of tradi...
# 9   The design is absolutely stunning, very nice r...
# 10  Great location and warm staffs. Room was a bit...
# 11  I love the staff, especially Iman at the front...
# 12                                      All the staff
# 13  Well thought bedrooms, very classy and comfort...
# 14  I like the room design. Shower and bedding are...

# %%
# The path should lead to your copy of chromedriver
driver = webdriver.Chrome('/Users/yt.hao/Desktop/BU/Study/CS506/cs506-spring2018-hw3-XintongHao-master/chromedriver')
url = "https://www.booking.com/searchresults.html?aid=304142&label=gen173nr-1FCAEoggJCAlhYSDNYBHIFdXNfbWGIAQGYATG4AQfIAQ3YAQHoAQH4AQKSAgF5qAID&sid=e0a0a3e08ec21a5cb741e08081e8f564&class_interval=1&dest_id=20088325&dest_type=city&from_sf=1&group_adults=2&group_children=0&label_click=undef&no_rooms=1&raw_dest_type=city&room1=A%2CA&rows=15&sb_price_type=total&search_selected=1&src=index&ss=New%20York%2C%20New%20York%20State%2C%20USA&ss_raw=new%20york&ssb=empty&=&=&nflt=di%3D929%3Bclass%3D1%3B&rsf=class-1&lsf=class%7C1%7C16"
# url = "https://www.booking.com/searchresults.html?label=gen173nr-1DCAEoggJCAlhYSDNYBHIFdXNfbWGIAQGYATG4AQfIAQ3YAQPoAQH4AQKSAgF5qAID&sid=991709bb93b40898e2ebcc9f2e20ade5&class_interval=1&dest_id=20088325&dest_type=city&from_sf=1&group_adults=2&group_children=0&label_click=undef&nflt=di%3D929%3B&no_rooms=1&pop_filter_id=di-929&pop_filter_pos=0&pop_filter_rank=2&raw_dest_type=city&room1=A%2CA&sb_price_type=total&search_selected=1&src=index&src_elem=sb&ss=New%20York%2C%20New%20York%20State%2C%20USA&ss_raw=new%20york&ssb=empty"
# Open the page in Selenium driver instance
driver.get(url)

# %%
hotel_name = []
class_rating = []
rating = []

# %%
def get_hotels(driver, hotel_name, class_rating, rating):

    for element in driver.find_elements_by_class_name("sr_item_no_dates"):
        names = element.find_elements_by_class_name('sr-hotel__name')
        name = names[0]
        hotel_name.append(name.text)
        print(name.text)
    #     for name in names:
    #         hotel_name.append(name.text)
    #         print(name.text)
        if (len(element.find_elements_by_class_name('review-score-badge') )== 0):
            rating.append(None)
            print(None)
        else:
            rates = element.find_elements_by_class_name('review-score-badge')
            rate = rates[0]
            rating.append(rate.text)
            print(rate.text)

        if (len(element.find_elements_by_class_name('review-score-widget__text')) == 0):
            class_rating.append(None)
            print(None)
        else:
            class_rates = element.find_elements_by_class_name('review-score-widget__text')
            class_rate = class_rates[0]
            class_rating.append(class_rate.text)
            print(class_rate.text)
    print(hotel_name)
#     df=pd.DataFrame(hotel_name,columns=['hotel_name'])
#     df['class_rating'] = class_rating
#     df['rating'] = rating
        

    print("===========")

# %%
get_hotels(driver, hotel_name, class_rating, rating)
# Out:
# Bowery Grand Hotel
# 5.0
# Review score
# ['Bowery Grand Hotel', 'Bowery Grand Hotel', 'Bowery Grand Hotel']
# ===========

# %%
df
# Out:
#                                            hotel_name class_rating rating
# 0                                       Tribeca Lofts    Very Good    8.1
# 1       Luxury Two Bedroom Apartment - Midtown West J         None   None
# 2                                   Freehand New York      Awesome    9.0
# 3                                  Gramercy Townhouse         None   None
# 4                           The Hotel at Times Square    Very Good    8.0
# 5                                    The Watson Hotel         Good    7.8
# 6                          Apartments Upper West Side         None   None
# 7   Residence Inn by Marriott New York Manhattan/T...    Very Good    8.2
# 8                               Radio City Apartments    Very Good    8.5
# 9                                    Heart of Midtown         None   None
# 10      Luxury Two Bedroom Apartment - Midtown West G    Excellent    8.6
# 11  Fairfield Inn & Suites by Marriott New York Do...    Excellent    8.9
# 12                              Archer Hotel New York      Awesome    9.0
# 13                                    Hotel 50 Bowery      Awesome    9.2
# 14                      Hudson New York, Central Park         Good    7.2

# %%
from selenium.common.exceptions import NoSuchElementException

page_number = 1
while True:
    try:
        link = driver.find_element_by_link_text(str(page_number))
        print(link.text)
#         driver.get(link.text)
#         get_hotels(driver)
    except NoSuchElementException:
        break
    link.click()
    
    
    
    driver.get(driver.current_url)
#     get_hotels(driver)

    for element in driver.find_elements_by_class_name("sr_item_no_dates"):
        names = element.find_elements_by_class_name('sr-hotel__name')
        name = names[0]
        hotel_name.append(name.text)
        print(name.text)
    #     for name in names:
    #         hotel_name.append(name.text)
    #         print(name.text)
        if (len(element.find_elements_by_class_name('review-score-badge') )== 0):
            rating.append(None)
            print(None)
        else:
            rates = element.find_elements_by_class_name('review-score-badge')
            rate = rates[0]
            rating.append(rate.text)
            print(rate.text)

        if (len(element.find_elements_by_class_name('review-score-widget__text')) == 0):
            class_rating.append(None)
            print(None)
        else:
            class_rates = element.find_elements_by_class_name('review-score-widget__text')
            class_rate = class_rates[0]
            class_rating.append(class_rate.text)
            print(class_rate.text)    
    
    
    
    print (driver.current_url)   
    print("===========")
    
    page_number += 1
# Out:
# 1
# NYC Apartment
# 9.2
# Awesome
# Apartment in Hell's Kitchen
# 7.2
# Good
# Full Studio in Central New York
# 8.6
# Excellent
# Three-Bedroom Apartment West 25th Street
# 7.1
# Good
# Manhattan Studio Apartments
# 7.3
# Good
# Four Bedroom Apartment - Eldridge St. #38
# 7.0
# Good
# Apartment near Times Square
# 8.5
# Very Good
# Broome Street Apartment - Lower East Side #19
# 7.4
# Good
# Central Park West Hostel
# 5.9
# Review score
# U.S. Pacific Hotel
# 6.1
# Review score
# Morningside Inn
# 5.5
# Review score
# Three Bedroom Apartment - West 148th Street
# 8.1
# Very Good
# Near the Central Park, in New York
# 8.1
# Very Good
# The Grand NYC Apartments
# 5.3
# Review score
# World Hotel
# 4.7
# Review score
# https://www.booking.com/searchresults.html?aid=304142&label=gen173nr-1FCAEoggJCAlhYSDNYBHIFdXNfbWGIAQGYATG4AQfIAQ3YAQHoAQH4AQKSAgF5qAID&sid=9f54d9b471e153a05becb7f53d06a3ed&class_interval=1&dest_id=20088325&dest_type=city&dtdisc=0&from_sf=1&group_adults=2&group_children=0&inac=0&index_postcard=0&label_click=undef&lsf=class%7C1%7C16&nflt=di%3D929%3Bclass%3D1%3B&no_rooms=1&postcard=0&raw_dest_type=city&room1=A%2CA&sb_price_type=total&search_selected=1&src=index&ss=New%20York%2C%20New%20York%20State%2C%20USA&ss_all=0&ss_raw=new%20york&ssb=empty&sshis=0&rows=15
# ===========
# 2
# Bowery Grand Hotel
# 5.0
# Review score
# https://www.booking.com/searchresults.html?aid=304142&label=gen173nr-1FCAEoggJCAlhYSDNYBHIFdXNfbWGIAQGYATG4AQfIAQ3YAQHoAQH4AQKSAgF5qAID&sid=9f54d9b471e153a05becb7f53d06a3ed&class_interval=1&dest_id=20088325&dest_type=city&from_sf=1&group_adults=2&group_children=0&label_click=undef&lsf=class%7C1%7C16&nflt=di%3D929%3Bclass%3D1%3B&no_rooms=1&raw_dest_type=city&room1=A%2CA&sb_price_type=total&search_selected=1&src=index&ss=New%20York%2C%20New%20York%20State%2C%20USA&ss_raw=new%20york&ssb=empty&rows=15&offset=15
# ===========

# %%
df=pd.DataFrame(hotel_name,columns=['hotel_name'])
df['class_rating'] = class_rating
df['rating'] = rating
df
# Out:
#                                        hotel_name  class_rating rating
# 0                                   NYC Apartment       Awesome    9.2
# 1                     Apartment in Hell's Kitchen          Good    7.2
# 2                 Full Studio in Central New York     Excellent    8.6
# 3        Three-Bedroom Apartment West 25th Street          Good    7.1
# 4                     Manhattan Studio Apartments          Good    7.3
# 5       Four Bedroom Apartment - Eldridge St. #38          Good    7.0
# 6                     Apartment near Times Square     Very Good    8.5
# 7   Broome Street Apartment - Lower East Side #19          Good    7.4
# 8                        Central Park West Hostel  Review score    5.9
# 9                              U.S. Pacific Hotel  Review score    6.1
# 10                                Morningside Inn  Review score    5.5
# 11    Three Bedroom Apartment - West 148th Street     Very Good    8.1
# 12             Near the Central Park, in New York     Very Good    8.1
# 13                       The Grand NYC Apartments  Review score    5.3
# 14                                    World Hotel  Review score    4.7
# 15                             Bowery Grand Hotel  Review score    5.0

# %%
import pandas as pd
df=pd.DataFrame(hotel_name,columns=['hotel_name'])
df['class_rating'] = class_rating
df['rating'] = rating

df
# Out:
#                                            hotel_name class_rating rating
# 0                                       Tribeca Lofts    Very Good    8.1
# 1       Luxury Two Bedroom Apartment - Midtown West J         None   None
# 2                                   Freehand New York      Awesome    9.0
# 3                                  Gramercy Townhouse         None   None
# 4                           The Hotel at Times Square    Very Good    8.0
# 5                                    The Watson Hotel         Good    7.8
# 6                          Apartments Upper West Side         None   None
# 7   Residence Inn by Marriott New York Manhattan/T...    Very Good    8.2
# 8                               Radio City Apartments    Very Good    8.5
# 9                                    Heart of Midtown         None   None
# 10      Luxury Two Bedroom Apartment - Midtown West G    Excellent    8.6
# 11  Fairfield Inn & Suites by Marriott New York Do...    Excellent    8.9
# 12                              Archer Hotel New York      Awesome    9.0
# 13                                    Hotel 50 Bowery      Awesome    9.2
# 14                      Hudson New York, Central Park         Good    7.2

# %%
print(len(hotel_name))
# Out:
# 15

# %%
def get_hotel_info(driver):
    # Use XPath to get all HTML elements corresponding to videos
#     hotels = driver.find_elements_by_xpath("""//*[@id="hotellist_inner"]""")
    
    
    
    for i in range(1,20):
        hotel = driver.find_elements_by_xpath("""//*[@id="hotellist_inner"]/div[{}]/div[2]/div[1]/div[1]/h3/a/span[1]""".format(i))
        
        for h in hotel:
            name = driver.find_element_by_class_name("sr-hotel__name")
            print("===========")
            print(i)
            print(name.text)

get_hotel_info(driver)
# Out:
# ===========
# 1
# Radisson Martinique on Broadway
# ===========
# 2
# Radisson Martinique on Broadway
# ===========
# 4
# Radisson Martinique on Broadway
# ===========
# 5
# Radisson Martinique on Broadway
# ===========
# 9
# Radisson Martinique on Broadway
# ===========
# 10
# Radisson Martinique on Broadway
# ===========
# 11
# Radisson Martinique on Broadway
# ===========
# 12
# Radisson Martinique on Broadway
# ===========
# 13
# Radisson Martinique on Broadway
# ===========
# 14
# Radisson Martinique on Broadway
# ===========
# 15
# Radisson Martinique on Broadway
# ===========
# 16
# Radisson Martinique on Broadway
# ===========
# 17
# Radisson Martinique on Broadway
# ===========
# 18
# Radisson Martinique on Broadway
# ===========
# 19
# Radisson Martinique on Broadway

# %%
df
# Out:
#                                            hotel_name class_rating rating
# 0                                       Tribeca Lofts    Very Good    8.1
# 1       Luxury Two Bedroom Apartment - Midtown West J         None   None
# 2                                   Freehand New York      Awesome    9.0
# 3                                  Gramercy Townhouse         None   None
# 4                           The Hotel at Times Square    Very Good    8.0
# 5                                    The Watson Hotel         Good    7.8
# 6                          Apartments Upper West Side         None   None
# 7   Residence Inn by Marriott New York Manhattan/T...    Very Good    8.2
# 8                               Radio City Apartments    Very Good    8.5
# 9                                    Heart of Midtown         None   None
# 10      Luxury Two Bedroom Apartment - Midtown West G    Excellent    8.6
# 11  Fairfield Inn & Suites by Marriott New York Do...    Excellent    8.9
# 12                              Archer Hotel New York      Awesome    9.0
# 13                                    Hotel 50 Bowery      Awesome    9.2
# 14                      Hudson New York, Central Park         Good    7.2

# %%
get_youtube_videos(driver)
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="10adfb2614a4f814d8ca85121f40aa12", element="0.8605301136508028-2")>]
# <selenium.webdriver.remote.webelement.WebElement (session="10adfb2614a4f814d8ca85121f40aa12", element="0.8605301136508028-2")>
